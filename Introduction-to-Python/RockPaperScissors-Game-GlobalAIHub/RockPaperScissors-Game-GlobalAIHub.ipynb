# %% [markdown]
# # You are a game developer :)
#
# In this practical exercise you are a game developer. You will program your first game – Rock, Paper, Scissors.
#
# If you are not familiar with the game, you can read about it here: https://en.wikipedia.org/wiki/Rock_paper_scissors.
#
# You will program the game step by step. Please read the instructions carefully. There are hints and important explanations that will help you with this exercise.

# %% [markdown]
# ##Warm up
#
# Each player can choose between the three actions "rock", "paper" and "scissors". First, you need to create a list that contains all possible actions.

# %%
#Please create a list containing the three actions of the game.
action_list = ['rock', 'paper', 'scissors']

# %% [markdown]
# # Choose an action
#
# Now you have the list with the actions ready. The next step is to let Python randomly choose an action from this list. Each player has to make a choice, so Python has to make a choice for player 1 and another one for player 2.
#
# 📌The built-in module "random" can help you with this. As you might remember from previous lessons you can use the .randint() method to generate random numbers.
#
# 📌📌There is another method in the random module called .choice(). It takes a list as input and selects an item randomly from that list.

# %%
#Import the random library
import random

#Select a random action for each player
player1_choice = random.choice(action_list)
player2_choice = action_list[random.randint(0,2)]

#Use the print function to print the players choices
print("Player1:", player1_choice)
print("Player2:", player2_choice)
# Out:
# Player1: scissors
# Player2: paper

# %% [markdown]
# # Determine the winner
#
# So, who won? To determine the winner, you first have to specify all possible outcomes of the game. Then you can use conditional statements to specify which outcome will lead to a win for player 1 or player 2, or a tie.
#
# First, let's start with the outcome that both users chose the same action: a tie!
# In case of a tie, the game should print the message "Tie! Both players chose the same action." to the screen.
#
# 📌Use conditional statements to check whether the players actions are equal to each other and *if* this condition is true the message should be printed.

# %%
#1 - Tie Condition
#Please write an if statement to check if the players chose the same action
if player1_choice == player2_choice:
  print("Tie! Both player chose same action.")

# %% [markdown]
# Now, let's focus on the remaining outcomes. We have three different actions: rock, paper and scissors.
#
# This is a list of all the possible combinations (without those that result in a tie):
#
# 1.   (paper, rock)
# 2.   (paper, scissors)
# 3.   (scissors, rock)
# 4.   (scissors, paper)
# 5.   (rock, paper)
# 6.   (rock, scissors)
#
# You need to check all these conditions in order to determine the winner.
#
# 📌You can use the "and" operator to combine two actions in one conditional statement.
#
# 📌📌Another approach is using nested if statements to check whether the action of player 2 beats the action of player 1.
#
# 🧨💣In the cell, first copy the code you wrote for "Tie" conditions. Then continue to add the other outcomes using "elif".

# %%
#Copy your code of the tie-conditions here
#1 - Tie Condition
if player1_choice == player2_choice:
  print("Tie! Both player choice same action.")

#Method 2 Nested if statements

elif player1_choice == 'paper':
  if player2_choice == 'rock':
    print("Winner is: Player 1")
  else:
    print("Winner is: Player 2")

elif player1_choice == 'rock':
  if player2_choice == 'paper':
    print("Winner is: Player 2")
  else:
    print("Winner is: Player 1")

elif player1_choice == 'scissors':
  if player2_choice == 'paper':
    print("Winner is: Player 1")
  else:
    print("Winner is: Player 2")
# Out:
# Winner is: Player 1

# %% [markdown]
# # Best of 3 or 5 or single round ? :)
#
# Now that you have your game set, let's also ask the users how many rounds they want to play.
#
# 📌 You can use the input function for this.
#
# And because there are multiple rounds, you need to keep track of the score. For this, you need to create a variable for each player that is 0 in the beginning.

# %%
#Please ask the user how many rounds they want to play
total_round = input("How many rounds do you want to play? ")

#Scores of players
player1_score = 0
player2_score = 0
# Out:
# How many rounds do you want to play? 2

# %% [markdown]
# # Use a for loop to specify the number of rounds
# The user specified how many rounds he or she wants to play.
#
# One way to use this information is to put the game inside of a for loop.
#
# 📌 You can use a for loop and the range() function to repeat the loop for a specified number of times.
#
# 📌📌 Don't forget to convert the user input to the data type integer. You can use the int() function for this.
#
# 📌📌📌 Don't forget to increment or add 1 to the score of the players that win, and print the current score after each round. You can use the assignment operator +=1 for this.

# %%
#Collect all the components of your program to run it in a for loop
#Import the random library
import random

#Add the code to create a list containing the three actions of the game.
action_list = ['rock', 'paper', 'scissors']

#Add the code to set the scores of players to 0
player1_score = 0
player2_score = 0

#Add the code to ask the user how many rounds they want to play
total_round = input("How many rounds do you want to play? ")

#Write a for loop and put the game inside
for i in range(int(total_round)):

  #Add the code to select a random action for each player
  player1_choice = random.choice(action_list)
  player2_choice = action_list[random.randint(0,2)]

  #Add the code to print the players choices
  print("Player1:", player1_choice)
  print("Player2:", player2_choice)

  #Add the tie condition
  if player1_choice == player2_choice:
    print("Tie! Both player chose same action.")

  #Add the remaining condition
  elif player1_choice == 'paper':
    if player2_choice == 'rock':
      print("Winner is: Player 1")
      player1_score +=1
    else:
      print("Winner is: Player 2")
      player2_score +=1

  elif player1_choice == 'rock':
    if player2_choice == 'paper':
      print("Winner is: Player 2")
      player2_score +=1
    else:
      print("Winner is: Player 1")
      player1_score +=1

  elif player1_choice == 'scissors':
    if player2_choice == 'paper':
      print("Winner is: Player 1")
      player1_score +=1
    else:
      print("Winner is: Player 2")
      player2_score +=1

  #print the score
  print("Score:", "Player1 =",player1_score, "Player2 =",player2_score)
# Out:
# How many rounds do you want to play? 2
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 0 Player2 = 0
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1 Player2 = 0

# %% [markdown]
# # Use a while loop to specify the number of rounds - Part 1
#
# In this module we also learned about while loops. Another way to play the game over and over again is using a while loop.
#
# This time, let's put the game inside a while loop.
#
# 📌 You can directly use the value *True* to specify that the while loop should be executed.
#
# 💣 By the way: Another very common name for True/False values is "**Boolean values**" or "**Bools**" in short.
#
# 🧨🧨 Caution! Since we run the game in an while loop, you have to stop the game manually. Otherwise it will run infinitely.

# %%
#Collect all the components of your program to run it in a while loop
#Import the random library
import random

#Add the code to create a list containing the three actions of the game.
action_list = ['rock', 'paper', 'scissors']

#Add the code to set the scores of players to 0
player1_score = 0
player2_score = 0

#Write a while loop and put the game inside
while True:

  #Add the code to select a random action for each player
  player1_choice = random.choice(action_list)
  player2_choice = action_list[random.randint(0,2)]

  #Add the code to print the players choices
  print("Player1:", player1_choice)
  print("Player2:", player2_choice)

  #Add the tie condition
  if player1_choice == player2_choice:
    print("Tie! Both player chose same action.")

  #Add the remaining condition
  elif player1_choice == 'paper':
    if player2_choice == 'rock':
      print("Winner is: Player 1")
      player1_score +=1
    else:
      print("Winner is: Player 2")
      player2_score +=1

  elif player1_choice == 'rock':
    if player2_choice == 'paper':
      print("Winner is: Player 2")
      player2_score +=1
    else:
      print("Winner is: Player 1")
      player1_score +=1

  elif player1_choice == 'scissors':
    if player2_choice == 'paper':
      print("Winner is: Player 1")
      player1_score +=1
    else:
      print("Winner is: Player 2")
      player2_score +=1

  #print the score
  print("Score:", "Player1 =",player1_score, "Player2 =",player2_score)
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 867 Player2 = 874
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 867 Player2 = 875
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 867 Player2 = 875
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 867 Player2 = 876
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 867 Player2 = 876
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 868 Player2 = 876
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 868 Player2 = 876
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 868 Player2 = 877
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 868 Player2 = 877
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 868 Player2 = 877
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 869 Player2 = 877
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 869 Player2 = 878
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 870 Player2 = 878
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 870 Player2 = 878
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 870 Player2 = 879
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 870 Player2 = 880
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 871 Player2 = 880
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 871 Player2 = 880
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 871 Player2 = 881
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 872 Player2 = 881
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 872 Player2 = 881
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 873 Player2 = 881
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 874 Player2 = 881
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 874 Player2 = 882
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 874 Player2 = 882
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 874 Player2 = 882
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 875 Player2 = 882
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 876 Player2 = 882
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 877 Player2 = 882
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 877 Player2 = 882
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 877 Player2 = 883
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 878 Player2 = 883
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 878 Player2 = 883
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 879 Player2 = 883
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 879 Player2 = 884
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 880 Player2 = 884
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 880 Player2 = 884
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 880 Player2 = 885
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 880 Player2 = 885
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 880 Player2 = 886
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 880 Player2 = 887
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 880 Player2 = 888
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 880 Player2 = 888
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 880 Player2 = 889
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 881 Player2 = 889
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 881 Player2 = 889
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 881 Player2 = 890
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 881 Player2 = 891
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 882 Player2 = 891
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 882 Player2 = 892
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 882 Player2 = 893
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 883 Player2 = 893
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 883 Player2 = 894
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 883 Player2 = 894
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 883 Player2 = 895
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 884 Player2 = 895
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 884 Player2 = 895
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 884 Player2 = 896
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 884 Player2 = 897
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 885 Player2 = 897
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 885 Player2 = 898
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 885 Player2 = 898
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 886 Player2 = 898
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 887 Player2 = 898
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 887 Player2 = 898
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 888 Player2 = 898
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 888 Player2 = 898
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 889 Player2 = 898
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 890 Player2 = 898
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 890 Player2 = 899
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 890 Player2 = 900
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 890 Player2 = 901
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 891 Player2 = 901
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 891 Player2 = 902
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 891 Player2 = 902
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 891 Player2 = 903
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 892 Player2 = 903
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 892 Player2 = 903
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 892 Player2 = 904
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 892 Player2 = 905
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 892 Player2 = 905
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 892 Player2 = 906
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 892 Player2 = 906
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 893 Player2 = 906
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 893 Player2 = 907
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 893 Player2 = 908
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 894 Player2 = 908
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 894 Player2 = 909
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 894 Player2 = 909
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 895 Player2 = 909
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 895 Player2 = 910
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 895 Player2 = 911
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 895 Player2 = 912
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 896 Player2 = 912
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 896 Player2 = 912
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 896 Player2 = 913
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 897 Player2 = 913
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 898 Player2 = 913
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 899 Player2 = 913
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 900 Player2 = 913
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 901 Player2 = 913
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 901 Player2 = 913
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 901 Player2 = 913
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 902 Player2 = 913
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 903 Player2 = 913
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 904 Player2 = 913
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 904 Player2 = 913
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 904 Player2 = 913
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 905 Player2 = 913
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 905 Player2 = 913
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 906 Player2 = 913
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 906 Player2 = 914
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 906 Player2 = 915
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 906 Player2 = 916
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 906 Player2 = 917
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 906 Player2 = 917
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 907 Player2 = 917
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 908 Player2 = 917
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 909 Player2 = 917
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 909 Player2 = 917
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 909 Player2 = 918
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 909 Player2 = 919
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 910 Player2 = 919
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 911 Player2 = 919
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 911 Player2 = 919
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 911 Player2 = 919
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 912 Player2 = 919
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 912 Player2 = 920
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 913 Player2 = 920
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 913 Player2 = 921
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 914 Player2 = 921
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 915 Player2 = 921
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 915 Player2 = 921
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 915 Player2 = 921
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 915 Player2 = 922
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 915 Player2 = 922
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 915 Player2 = 922
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 915 Player2 = 923
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 916 Player2 = 923
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 917 Player2 = 923
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 918 Player2 = 923
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 919 Player2 = 923
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 919 Player2 = 923
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 920 Player2 = 923
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 921 Player2 = 923
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 921 Player2 = 924
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 921 Player2 = 924
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 921 Player2 = 924
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 922 Player2 = 924
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 923 Player2 = 924
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 923 Player2 = 924
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 924 Player2 = 924
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 924 Player2 = 924
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 924 Player2 = 924
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 925 Player2 = 924
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 926 Player2 = 924
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 926 Player2 = 925
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 926 Player2 = 926
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 927 Player2 = 926
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 927 Player2 = 926
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 927 Player2 = 926
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 927 Player2 = 926
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 927 Player2 = 927
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 927 Player2 = 928
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 927 Player2 = 928
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 927 Player2 = 928
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 928 Player2 = 928
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 929 Player2 = 928
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 929 Player2 = 929
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 929 Player2 = 929
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 930 Player2 = 929
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 931 Player2 = 929
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 931 Player2 = 930
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 931 Player2 = 930
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 932 Player2 = 930
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 933 Player2 = 930
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 933 Player2 = 930
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 933 Player2 = 931
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 934 Player2 = 931
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 934 Player2 = 932
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 934 Player2 = 932
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 935 Player2 = 932
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 935 Player2 = 933
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 936 Player2 = 933
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 936 Player2 = 934
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 936 Player2 = 934
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 936 Player2 = 934
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 936 Player2 = 934
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 936 Player2 = 935
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 936 Player2 = 936
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 937 Player2 = 936
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 938 Player2 = 936
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 938 Player2 = 936
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 939 Player2 = 936
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 939 Player2 = 936
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 940 Player2 = 936
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 940 Player2 = 937
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 941 Player2 = 937
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 941 Player2 = 937
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 941 Player2 = 937
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 942 Player2 = 937
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 943 Player2 = 937
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 944 Player2 = 937
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 944 Player2 = 938
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 944 Player2 = 939
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 944 Player2 = 939
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 944 Player2 = 939
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 944 Player2 = 940
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 945 Player2 = 940
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 945 Player2 = 940
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 945 Player2 = 940
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 945 Player2 = 940
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 945 Player2 = 941
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 945 Player2 = 942
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 946 Player2 = 942
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 946 Player2 = 942
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 947 Player2 = 942
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 947 Player2 = 942
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 947 Player2 = 942
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 948 Player2 = 942
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 949 Player2 = 942
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 950 Player2 = 942
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 950 Player2 = 942
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 950 Player2 = 943
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 951 Player2 = 943
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 951 Player2 = 944
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 951 Player2 = 945
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 951 Player2 = 946
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 951 Player2 = 947
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 951 Player2 = 947
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 951 Player2 = 948
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 952 Player2 = 948
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 952 Player2 = 949
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 952 Player2 = 950
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 953 Player2 = 950
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 953 Player2 = 951
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 954 Player2 = 951
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 954 Player2 = 951
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 954 Player2 = 952
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 955 Player2 = 952
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 955 Player2 = 953
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 955 Player2 = 953
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 956 Player2 = 953
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 956 Player2 = 954
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 957 Player2 = 954
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 958 Player2 = 954
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 958 Player2 = 955
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 958 Player2 = 955
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 959 Player2 = 955
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 959 Player2 = 955
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 960 Player2 = 955
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 961 Player2 = 955
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 961 Player2 = 956
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 961 Player2 = 956
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 961 Player2 = 956
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 961 Player2 = 956
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 961 Player2 = 957
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 961 Player2 = 957
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 962 Player2 = 957
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 962 Player2 = 957
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 963 Player2 = 957
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 963 Player2 = 957
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 963 Player2 = 957
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 964 Player2 = 957
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 965 Player2 = 957
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 965 Player2 = 957
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 966 Player2 = 957
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 966 Player2 = 957
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 966 Player2 = 957
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 967 Player2 = 957
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 967 Player2 = 957
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 967 Player2 = 958
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 967 Player2 = 959
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 967 Player2 = 959
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 968 Player2 = 959
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 969 Player2 = 959
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 969 Player2 = 960
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 969 Player2 = 961
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 970 Player2 = 961
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 970 Player2 = 962
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 971 Player2 = 962
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 971 Player2 = 962
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 971 Player2 = 963
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 971 Player2 = 963
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 971 Player2 = 963
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 971 Player2 = 963
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 971 Player2 = 963
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 971 Player2 = 963
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 972 Player2 = 963
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 972 Player2 = 963
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 973 Player2 = 963
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 974 Player2 = 963
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 975 Player2 = 963
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 975 Player2 = 964
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 975 Player2 = 965
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 976 Player2 = 965
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 976 Player2 = 966
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 976 Player2 = 966
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 977 Player2 = 966
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 978 Player2 = 966
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 978 Player2 = 966
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 979 Player2 = 966
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 979 Player2 = 966
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 980 Player2 = 966
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 980 Player2 = 967
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 980 Player2 = 967
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 980 Player2 = 968
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 981 Player2 = 968
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 982 Player2 = 968
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 982 Player2 = 969
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 983 Player2 = 969
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 983 Player2 = 970
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 984 Player2 = 970
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 985 Player2 = 970
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 986 Player2 = 970
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 986 Player2 = 970
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 986 Player2 = 971
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 987 Player2 = 971
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 988 Player2 = 971
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 989 Player2 = 971
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 990 Player2 = 971
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 991 Player2 = 971
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 991 Player2 = 972
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 992 Player2 = 972
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 992 Player2 = 973
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 993 Player2 = 973
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 993 Player2 = 974
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 994 Player2 = 974
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 994 Player2 = 975
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 994 Player2 = 976
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 994 Player2 = 976
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 994 Player2 = 977
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 994 Player2 = 977
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 995 Player2 = 977
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 996 Player2 = 977
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 997 Player2 = 977
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 997 Player2 = 978
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 998 Player2 = 978
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 998 Player2 = 979
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 998 Player2 = 979
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 999 Player2 = 979
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1000 Player2 = 979
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1000 Player2 = 979
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1001 Player2 = 979
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1001 Player2 = 980
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1001 Player2 = 981
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1001 Player2 = 981
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1001 Player2 = 982
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1002 Player2 = 982
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1002 Player2 = 983
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1002 Player2 = 983
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1003 Player2 = 983
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1003 Player2 = 983
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1003 Player2 = 983
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1004 Player2 = 983
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1004 Player2 = 983
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1004 Player2 = 983
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1005 Player2 = 983
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1005 Player2 = 983
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1005 Player2 = 983
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1006 Player2 = 983
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1006 Player2 = 983
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1007 Player2 = 983
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1007 Player2 = 983
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1007 Player2 = 984
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1007 Player2 = 984
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1007 Player2 = 984
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1007 Player2 = 984
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1007 Player2 = 985
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1008 Player2 = 985
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1009 Player2 = 985
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1009 Player2 = 986
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1009 Player2 = 987
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1009 Player2 = 987
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1009 Player2 = 987
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1009 Player2 = 988
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1009 Player2 = 989
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1009 Player2 = 989
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1010 Player2 = 989
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1010 Player2 = 990
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1011 Player2 = 990
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1011 Player2 = 990
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1012 Player2 = 990
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1012 Player2 = 991
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1013 Player2 = 991
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1014 Player2 = 991
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1014 Player2 = 992
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1014 Player2 = 993
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1014 Player2 = 993
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1015 Player2 = 993
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1016 Player2 = 993
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1017 Player2 = 993
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1017 Player2 = 994
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1017 Player2 = 995
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1017 Player2 = 996
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1018 Player2 = 996
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1018 Player2 = 997
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1018 Player2 = 998
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1018 Player2 = 998
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1018 Player2 = 998
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1018 Player2 = 998
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1018 Player2 = 999
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1018 Player2 = 999
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1018 Player2 = 1000
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1018 Player2 = 1000
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1019 Player2 = 1000
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1019 Player2 = 1001
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1019 Player2 = 1002
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1019 Player2 = 1002
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1019 Player2 = 1003
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1019 Player2 = 1004
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1020 Player2 = 1004
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1020 Player2 = 1004
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1020 Player2 = 1005
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1021 Player2 = 1005
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1022 Player2 = 1005
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1023 Player2 = 1005
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1023 Player2 = 1005
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1024 Player2 = 1005
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1024 Player2 = 1005
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1025 Player2 = 1005
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1026 Player2 = 1005
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1027 Player2 = 1005
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1027 Player2 = 1006
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1027 Player2 = 1006
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1028 Player2 = 1006
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1028 Player2 = 1007
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1028 Player2 = 1008
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1029 Player2 = 1008
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1029 Player2 = 1009
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1029 Player2 = 1009
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1030 Player2 = 1009
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1030 Player2 = 1009
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1030 Player2 = 1010
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1030 Player2 = 1011
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1030 Player2 = 1011
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1030 Player2 = 1011
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1030 Player2 = 1011
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1030 Player2 = 1012
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1031 Player2 = 1012
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1032 Player2 = 1012
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1033 Player2 = 1012
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1033 Player2 = 1013
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1033 Player2 = 1013
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1033 Player2 = 1014
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1033 Player2 = 1015
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1033 Player2 = 1016
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1033 Player2 = 1017
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1034 Player2 = 1017
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1034 Player2 = 1017
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1035 Player2 = 1017
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1036 Player2 = 1017
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1036 Player2 = 1018
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1036 Player2 = 1019
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1036 Player2 = 1020
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1037 Player2 = 1020
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1037 Player2 = 1021
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1037 Player2 = 1021
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1038 Player2 = 1021
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1038 Player2 = 1021
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1038 Player2 = 1022
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1039 Player2 = 1022
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1039 Player2 = 1022
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1039 Player2 = 1023
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1040 Player2 = 1023
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1041 Player2 = 1023
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1042 Player2 = 1023
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1042 Player2 = 1023
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1042 Player2 = 1023
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1043 Player2 = 1023
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1043 Player2 = 1024
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1043 Player2 = 1024
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1043 Player2 = 1025
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1044 Player2 = 1025
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1045 Player2 = 1025
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1046 Player2 = 1025
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1047 Player2 = 1025
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1047 Player2 = 1025
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1047 Player2 = 1025
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1047 Player2 = 1026
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1047 Player2 = 1026
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1048 Player2 = 1026
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1048 Player2 = 1027
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1048 Player2 = 1028
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1048 Player2 = 1029
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1048 Player2 = 1029
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1049 Player2 = 1029
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1049 Player2 = 1030
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1050 Player2 = 1030
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1050 Player2 = 1031
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1051 Player2 = 1031
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1051 Player2 = 1031
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1051 Player2 = 1032
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1051 Player2 = 1032
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1051 Player2 = 1032
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1051 Player2 = 1032
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1051 Player2 = 1033
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1051 Player2 = 1034
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1051 Player2 = 1035
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1052 Player2 = 1035
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1053 Player2 = 1035
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1053 Player2 = 1035
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1054 Player2 = 1035
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1054 Player2 = 1036
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1054 Player2 = 1036
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1055 Player2 = 1036
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1055 Player2 = 1036
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1055 Player2 = 1036
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1055 Player2 = 1037
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1055 Player2 = 1038
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1055 Player2 = 1039
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1056 Player2 = 1039
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1056 Player2 = 1040
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1056 Player2 = 1040
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1057 Player2 = 1040
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1057 Player2 = 1041
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1057 Player2 = 1041
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1057 Player2 = 1041
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1057 Player2 = 1042
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1057 Player2 = 1043
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1058 Player2 = 1043
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1058 Player2 = 1043
# Player1: rock
# Player2: scissors
# ...
# Score: Player1 = 1242 Player2 = 1229
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1243 Player2 = 1229
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1243 Player2 = 1230
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1244 Player2 = 1230
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1244 Player2 = 1230
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1245 Player2 = 1230
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1246 Player2 = 1230
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1247 Player2 = 1230
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1247 Player2 = 1231
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1247 Player2 = 1232
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1248 Player2 = 1232
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1248 Player2 = 1233
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1248 Player2 = 1233
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1248 Player2 = 1233
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1248 Player2 = 1233
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1249 Player2 = 1233
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1250 Player2 = 1233
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1251 Player2 = 1233
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1251 Player2 = 1233
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1252 Player2 = 1233
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1252 Player2 = 1233
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1252 Player2 = 1234
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1253 Player2 = 1234
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1253 Player2 = 1235
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1254 Player2 = 1235
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1254 Player2 = 1236
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1254 Player2 = 1236
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1255 Player2 = 1236
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1255 Player2 = 1236
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1255 Player2 = 1236
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1255 Player2 = 1236
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1255 Player2 = 1237
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1256 Player2 = 1237
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1256 Player2 = 1237
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1257 Player2 = 1237
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1257 Player2 = 1238
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1258 Player2 = 1238
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1259 Player2 = 1238
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1260 Player2 = 1238
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1261 Player2 = 1238
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1261 Player2 = 1239
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1261 Player2 = 1239
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1261 Player2 = 1239
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1261 Player2 = 1239
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1261 Player2 = 1239
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1261 Player2 = 1240
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1261 Player2 = 1241
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1261 Player2 = 1242
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1262 Player2 = 1242
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1262 Player2 = 1242
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1262 Player2 = 1243
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1262 Player2 = 1244
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1262 Player2 = 1244
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1262 Player2 = 1244
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1263 Player2 = 1244
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1264 Player2 = 1244
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1265 Player2 = 1244
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1266 Player2 = 1244
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1266 Player2 = 1244
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1267 Player2 = 1244
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1268 Player2 = 1244
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1269 Player2 = 1244
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1269 Player2 = 1245
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1269 Player2 = 1246
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1269 Player2 = 1246
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1270 Player2 = 1246
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1271 Player2 = 1246
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1271 Player2 = 1247
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1272 Player2 = 1247
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1272 Player2 = 1248
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1272 Player2 = 1249
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1273 Player2 = 1249
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1274 Player2 = 1249
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1274 Player2 = 1250
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1275 Player2 = 1250
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1275 Player2 = 1251
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1276 Player2 = 1251
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1277 Player2 = 1251
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1277 Player2 = 1251
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1277 Player2 = 1251
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1278 Player2 = 1251
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1279 Player2 = 1251
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1279 Player2 = 1251
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1279 Player2 = 1252
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1279 Player2 = 1253
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1280 Player2 = 1253
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1281 Player2 = 1253
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1281 Player2 = 1253
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1282 Player2 = 1253
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1282 Player2 = 1254
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1283 Player2 = 1254
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1283 Player2 = 1255
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1283 Player2 = 1255
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1283 Player2 = 1256
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1284 Player2 = 1256
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1284 Player2 = 1257
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1284 Player2 = 1257
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1284 Player2 = 1258
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1285 Player2 = 1258
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1285 Player2 = 1259
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1286 Player2 = 1259
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1286 Player2 = 1259
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1286 Player2 = 1260
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1286 Player2 = 1261
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1286 Player2 = 1262
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1286 Player2 = 1263
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1287 Player2 = 1263
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1288 Player2 = 1263
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1288 Player2 = 1264
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1288 Player2 = 1264
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1288 Player2 = 1264
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1288 Player2 = 1264
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1289 Player2 = 1264
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1289 Player2 = 1265
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1289 Player2 = 1265
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1290 Player2 = 1265
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1290 Player2 = 1266
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1291 Player2 = 1266
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1291 Player2 = 1267
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1292 Player2 = 1267
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1292 Player2 = 1267
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1293 Player2 = 1267
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1293 Player2 = 1268
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1294 Player2 = 1268
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1295 Player2 = 1268
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1296 Player2 = 1268
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1297 Player2 = 1268
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1297 Player2 = 1269
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1297 Player2 = 1270
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1297 Player2 = 1270
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1297 Player2 = 1270
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1298 Player2 = 1270
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1298 Player2 = 1271
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1299 Player2 = 1271
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1299 Player2 = 1272
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1299 Player2 = 1273
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1300 Player2 = 1273
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1300 Player2 = 1273
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1300 Player2 = 1273
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1300 Player2 = 1274
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1300 Player2 = 1274
# Player1: scissors
# Player2: scissors
# Tie! Both player chose same action.
# Score: Player1 = 1300 Player2 = 1274
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score: Player1 = 1300 Player2 = 1274
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1301 Player2 = 1274
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1301 Player2 = 1275
# Player1: scissors
# Player2: rock
# Winner is: Player 2
# Score: Player1 = 1301 Player2 = 1276
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1302 Player2 = 1276
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1303 Player2 = 1276
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1304 Player2 = 1276
# Player1: rock
# Player2: rock
# Tie! Both player chose same action.
# Score: Player1 = 1304 Player2 = 1276
# Player1: scissors
# Player2: paper
# Winner is: Player 1
# Score: Player1 = 1305 Player2 = 1276
# Player1: rock
# Player2: scissors
# Winner is: Player 1
# Score: Player1 = 1306 Player2 = 1276
# Player1: paper
# Player2: rock
# Winner is: Player 1
# Score: Player1 = 1307 Player2 = 1276
# Player1: rock
# Player2: paper
# Winner is: Player 2
# Score: Player1 = 1307 Player2 = 1277
# Player1: paper
# Player2: scissors
# Winner is: Player 2
# Score: Player1 = 1307 Player2 = 1278
# Player1: paper
# Player2: paper
# Tie! Both player chose same action.
# Score:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-68d04f3e44e5> in <module>
#      51
#      52   #print the score
# ---> 53   print("Score:", "Player1 =",player1_score, "Player2 =",player2_score)
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in write(self, string)
#     402             is_child = (not self._is_master_process())
#     403             # only touch the buffer in the IO thread to avoid races
# --> 404             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     405             if is_child:
#     406                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
# --> 205             self._event_pipe.send(b'')
#     206         else:
#     207             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# # Use a while loop to specify the number of rounds - Part 2
#
# Now the game runs infinitely and the user can end it manually. But there is a more efficient way to do this: Let's ask the user again how many rounds they want to play, just as you did for the game inside the for loop.
#
# To prevent an infinite loop, you need to add a round_counter that is 0 at the beginning. In each round, this counter needs to increase by 1.
#
# At the end of your while loop, you need to add an "if" condition to check whether the round_counter is equal to the number of rounds that we got from user as an input. If this is the case, we need to use "**break**" to end the game.
#
# Once we end the game, it would be nice to see a message that prints the winner to the screen. In case of a tie, it should print a message that the game ended in a tie.
#
# 📌 You can use "if" and "elif" statements to determine the winner at the end.

# %%
#Collect all the components of your program to run it in a while loop
#Import the random library
import random

#Add the code to create a list containing the three actions of the game.
action_list = ['rock', 'paper', 'scissors']

#Add the code to set the scores of players to 0
player1_score = 0
player2_score = 0
#Add a round_counter that is 0 at the beginning
round_counter = 0

#Add the code to ask the user how many rounds they want to play
total_round = input("How many rounds do you want to play? ")

#Write a while loop and put the game inside
while True:

  #increase round_counter by 1 and print it
  round_counter +=1
  print("Round number:", round_counter)

  #Add the code to select a random action for each player
  player1_choice = random.choice(action_list)
  player2_choice = action_list[random.randint(0,2)]

  #Add the code to print the players choices
  print("Player1:", player1_choice)
  print("Player2:", player2_choice)

  #Add the tie condition
  if player1_choice == player2_choice:
    print("Tie! Both player chose same action.")

  #Add the remaining condition
  elif player1_choice == 'paper':
    if player2_choice == 'rock':
      print("Winner is: Player 1")
      player1_score +=1
    else:
      print("Winner is: Player 2")
      player2_score +=1

  elif player1_choice == 'rock':
    if player2_choice == 'paper':
      print("Winner is: Player 2")
      player2_score +=1
    else:
      print("Winner is: Player 1")
      player1_score +=1

  elif player1_choice == 'scissors':
    if player2_choice == 'paper':
      print("Winner is: Player 1")
      player1_score +=1
    else:
      print("Winner is: Player 2")
      player2_score +=1

  #print the score
  print("Score:", "Player1 =",player1_score, "Player2 =",player2_score)

  #stop the while loop if the round_counter equals the number of total rounds
  if round_counter == int(total_round):
    break
#Print the outcome of the game by using conditional statements
if player1_score == player2_score:
  print("There is no winner, tie.")
elif player1_score > player2_score:
  print("Player 1 won with score", player1_score, ":", player2_score)
elif player1_score < player2_score:
  print("Player 2 won with score", player1_score, ":", player2_score)
